# %%
x = 4
y = 5
x + y
# Out:
# 9

# %%
# data types: strings
name = "jaden"

# %%
city = "memphis"

# %%
name
# Out:
# 'jaden'

# %%
city
# Out:
# 'memphis'

# %%
name = "jaden"
print(name)
# Out:
# jaden

# %%
print("hello,world!")
# Out:
# hello,world!

# %%
"hello world"
# Out:
# 'hello world'

# %%
input("hello, whats your name?")
# Out:
# hello, whats your name? jaden
# 'jaden'

# %%
name = input("hello, whats your name?")
print("hello,", name)
# Out:
# hello, whats your name? jaden
# hello, jaden
